# %% [markdown]
# # Train a Model on MNIST with FiftyOne and Torch

# %% [markdown]
# ## Import Libraries

# %%
import fiftyone as fo
import fiftyone.zoo as foz
import fiftyone.utils.random as four

# %%
import torch
from torch.utils.data import DataLoader
import numpy as np
import torchvision.transforms.v2 as transforms
from torchvision import tv_tensors
import matplotlib.pyplot as plt
import matplotlib.patches as plt_patches
from PIL import Image
import urllib.request

# %% [markdown]
# To run this recipe, you’ll need the mnist_training.py script, which contains a simple PyTorch training loop. The following cell will automatically download the file into your working directory so it can be imported directly.

# %%
url = "https://cdn.voxel51.com/tutorials_torch_dataset_examples/notebook_simple_training_example/mnist_training.py"
urllib.request.urlretrieve(url, "mnist_training.py")
# Out:
# ('mnist_training.py', <http.client.HTTPMessage at 0x18a97d70d10>)

# %%
url = "https://cdn.voxel51.com/tutorials_torch_dataset_examples/notebook_the_cache_field_names_argument/utils.py"
urllib.request.urlretrieve(url, "utils.py")
# Out:
# ('utils.py', <http.client.HTTPMessage at 0x18a97d39790>)

# %%
import mnist_training

# %%
# torch.multiprocessing.set_start_method('forkserver') Doesnt work on windows
torch.multiprocessing.set_forkserver_preload(['torch', 'fiftyone'])

# %% [markdown]
# ## Basic Training Example on MNIST

# %%
mnist = foz.load_zoo_dataset("mnist")
mnist.persistent = True
# Out:
# Split 'train' already downloaded
# Split 'test' already downloaded
# Loading existing dataset 'mnist'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
session = fo.launch_app(mnist, auto=False)
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %% [markdown]
# Now let’s say that for our training, we want to define some random subset of our trainset to be a validation set. We can easily do this with FiftyOne.

# %%
# remove existing 'train' or 'validation' tags if they exist
mnist.untag_samples(['train', 'validation'])

# create a random split, just on the samples not tagged 'test'
not_test = mnist.match_tags('test', bool=False)
four.random_split(not_test, {'train' : 0.9, 'validation' : 0.1})
print(mnist.count_sample_tags())
# Out:
# {'train': 54000, 'test': 10000, 'validation': 6000}

# %%
# subset if we want it
samples = []
samples += mnist.match_tags('train').take(1000).values('id')
for tag in ['test', 'validation']:
    samples += mnist.match_tags(tag).values('id')

subset = mnist.select(samples)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
import os
current_path = os.getcwd()

path_to_save_weights = current_path + "/mnist_weights"

# %%
mnist_training.main(subset, 10, 10, device, path_to_save_weights)
# Out:
# Average Train Loss =   3.852252: 100%|██████████| 63/63 [00:01<00:00, 45.63it/s]
# Average Validation Loss =   1.281961: 100%|██████████| 375/375 [00:02<00:00, 150.97it/s]
# New best lost achieved : 1.2664934581319491. Saving model...
# Average Train Loss =   0.441777: 100%|██████████| 63/63 [00:01<00:00, 44.11it/s]
# Average Validation Loss =   0.897705: 100%|██████████| 375/375 [00:02<00:00, 155.95it/s]
# New best lost achieved : 0.879171499868234. Saving model...
# Average Train Loss =   0.956404: 100%|██████████| 63/63 [00:01<00:00, 43.52it/s]
# Average Validation Loss =   0.568833: 100%|██████████| 375/375 [00:02<00:00, 156.93it/s]
# New best lost achieved : 0.5494623985569924. Saving model...
# Average Train Loss =   0.894667: 100%|██████████| 63/63 [00:01<00:00, 43.35it/s]
# Average Validation Loss =   0.520743: 100%|██████████| 375/375 [00:02<00:00, 148.43it/s]
# New best lost achieved : 0.5182197396531701. Saving model...
# Average Train Loss =   0.065636: 100%|██████████| 63/63 [00:01<00:00, 42.86it/s]
# Average Validation Loss =   0.242703: 100%|██████████| 375/375 [00:02<00:00, 155.47it/s]
# New best lost achieved : 0.24006225669011474. Saving model...
# Average Train Loss =   0.054023: 100%|██████████| 63/63 [00:01<00:00, 44.52it/s]
# Average Validation Loss =   0.185328: 100%|██████████| 375/375 [00:02<00:00, 152.05it/s]
# New best lost achieved : 0.18303052319089572. Saving model...
# Average Train Loss =   0.006056: 100%|██████████| 63/63 [00:01<00:00, 42.92it/s]
# Average Validation Loss =   0.116363: 100%|██████████| 375/375 [00:02<00:00, 162.16it/s]
# New best lost achieved : 0.11665831965696997. Saving model...
# Average Train Loss =   0.285662: 100%|██████████| 63/63 [00:01<00:00, 46.27it/s]
# Average Validation Loss =   0.119291: 100%|██████████| 375/375 [00:02<00:00, 153.70it/s]
# Average Train Loss =   0.034335: 100%|██████████| 63/63 [00:01<00:00, 45.71it/s]
# Average Validation Loss =   0.130721: 100%|██████████| 375/375 [00:02<00:00, 161.85it/s]
# Average Train Loss =   0.017060: 100%|██████████| 63/63 [00:01<00:00, 46.28it/s]
# Average Validation Loss =   0.222115: 100%|██████████| 375/375 [00:02<00:00, 165.41it/s]
# Average Validation Loss =   0.105206: 100%|██████████| 625/625 [00:09<00:00, 64.20it/s]
# Final Test Results:
# Loss = 0.10882228565048427
#               precision    recall  f1-score   support
#
#     0 - zero       0.97      0.98      0.97       980
#      1 - one       0.99      0.99      0.99      1135
#      2 - two       0.95      0.97      0.96      1032
#    3 - three       0.94      0.98      0.96      1010
#     4 - four       0.98      0.97      0.97       982
#     5 - five       0.99      0.96      0.97       892
#      6 - six       0.99      0.97      0.98       958
#    7 - seven       0.97      0.94      0.96      1028
#    8 - eight       0.98      0.95      0.96       974
#     9 - nine       0.92      0.97      0.94      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
